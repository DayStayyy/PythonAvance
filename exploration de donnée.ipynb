# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("merged_data.csv")
df
# Convert the temperature from Kelvin to Celsius, skipping over any invalid values
#df['t'] = pd.to_numeric(df['t'], errors='coerce')
#df['t'] = np.where(df['t'].isna(), np.nan, df['t'] - 273.15)

# Convert the date column to a datetime object
#df['date'] = pd.to_datetime(df['date'], format='%Y%m%d%H%M%S')

# Create a new DataFrame with the mean temperature by year
#mean_temp_by_year = df.groupby(df['date'].dt.year)['t'].mean()
#mean_temp_by_year
# Out:
#          numer_sta                 date    pmer  tend cod_tend   dd  \
# 0             7005  1996-01-01 00:00:00  100030   100        1  170
# 1             7015  1996-01-01 00:00:00  100020   100        1    0
# 2             7020  1996-01-01 00:00:00   99740   -50        8  180
# 3             7027  1996-01-01 00:00:00   99940     0        0  120
# 4             7037  1996-01-01 00:00:00  100010    90        0  190
# ...            ...                  ...     ...   ...      ...  ...
# 4541392      81401  2022-12-31 21:00:00  101010    50        5   50
# 4541393      81405  2022-12-31 21:00:00  101070   -20        5   60
# 4541394      81408  2022-12-31 21:00:00  101020    50        5   20
# 4541395      81415  2022-12-31 21:00:00      mq    mq       mq   70
# 4541396      89642  2022-12-31 21:00:00   98340  -390        8  100
#
#                 ff      t          td    u  ... nnuage2 ctype2 hnuage2  \
# 0         2.000000   2.89  275.950000   99  ...      mq     mq      mq
# ...

# %%
df.ff
# Out:
# 0           2.000000
# 1           0.000000
# 2           8.200000
# 3           4.100000
# 4           1.000000
#              ...
# 4541392     1.600000
# 4541393     3.300000
# 4541394     1.200000
# 4541395     1.500000
# 4541396    12.300000
# Name: ff, Length: 4541397, dtype: object

# %%
#df['date'] = pd.to_datetime(df['date'], format='%Y%m%d%H%M%S')
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
# Create a new DataFrame with the mean temperature by year
mean_temp_by_year = df.groupby(df['date'].dt.year)['t'].mean().reset_index()
mean_temp_by_year.rename(columns={'t': 'TMean'}, inplace=True)
mean_temp_by_year
# Out:
#     date      TMean
# 0   1996  14.020063
# 1   1997  14.899133
# 2   1998  14.697877
# 3   1999  14.716910
# 4   2000  14.591345
# 5   2001  14.757174
# 6   2002  14.705450
# 7   2003  14.888266
# 8   2004  14.748020
# 9   2005  14.777083
# 10  2006  15.074878
# 11  2007  14.955878
# 12  2008  14.487538
# 13  2009  14.828788
# 14  2010  14.057431
# 15  2011  15.119831
# 16  2012  14.559869
# 17  2013  14.263538
# 18  2014  15.001602
# 19  2015  14.204845
# 20  2016  14.493114
# 21  2017  14.912292
# 22  2018  15.173137
# 23  2019  15.479841
# 24  2020  15.652178
# 25  2021  14.793742
# 26  2022  15.933596

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
df['ff'] = pd.to_numeric(df['ff'], errors='coerce')
df = df.dropna(subset=['ff'])

# Group the DataFrame by week and calculate the range of temperatures within each week
df_weekly = df.groupby(df['date'].dt.isocalendar().week)['ff'].apply(lambda x: np.ptp(x)).reset_index(name='range_temp')
df_weekly
# Plot the temperature ranges within each week using a bar chart
plt.bar(df_weekly['week'], df_weekly['range_temp'])
plt.xlabel('Week')
plt.ylabel('Temperature Range')
plt.title('Temperature Range Within Each Week')
plt.show()
# Out:
# C:\Users\rukab\AppData\Local\Temp\ipykernel_4668\2871898076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
# C:\Users\rukab\AppData\Local\Temp\ipykernel_4668\2871898076.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ff'] = pd.to_numeric(df['ff'], errors='coerce')

# %%
type(mean_temp_by_year.TMean)
# Out:
# pandas.core.series.Series

# %%
xpoints = mean_temp_by_year.date
ypoints = mean_temp_by_year.TMean
plt.plot(xpoints, ypoints)
plt.xlabel("year")
plt.ylabel("temp mean")
plt.legend(["temp mean","year"])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4541397 entries, 0 to 4541396
# Data columns (total 60 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   numer_sta    int64
#  1   date         datetime64[ns]
#  2   pmer         object
#  3   tend         object
#  4   cod_tend     object
#  5   dd           object
#  6   ff           object
#  7   t            float64
#  8   td           object
#  9   u            object
#  10  vv           object
#  11  ww           object
#  12  w1           object
#  13  w2           object
#  14  n            object
#  15  nbas         object
#  16  hbas         object
#  17  cl           object
#  18  cm           object
#  19  ch           object
#  20  pres         object
#  21  niv_bar      object
#  22  geop         object
#  23  tend24       object
#  24  tn12         object
#  25  tn24         object
#  26  tx12         object
#  27  tx24         object
#  28  tminsol      object
#  29  sw           object
# ...

# %%
df['dd'] = pd.to_numeric(df['dd'], errors='coerce')
df['eoliene_can_run'] = (df['dd'] > 4.16667) & (df['dd'] < 25)

# %%
r
# Out:
#                numer_sta          dd          t  Unnamed: 59  eoliene_can_run
# date
# 1996-01-01  24509.465909  148.500000  11.175159          NaN            False
# 1996-01-02  24809.559551  196.606742  11.232045          NaN            False
# 1996-01-03  25003.714932  145.520362   9.693756          NaN            False
# 1996-01-04  24777.799544  135.514874   9.657374          NaN            False
# 1996-01-05  24394.267574  157.052154  10.119478          NaN            False
# ...                  ...         ...        ...          ...              ...
# 2022-12-27  26994.824268  170.680851  11.922128          NaN            False
# 2022-12-28  27232.050000  171.186441  12.748093          NaN            False
# 2022-12-29  27293.404959  183.277311  13.405672          NaN            False
# 2022-12-30  27675.267490  164.811715  13.937736          NaN            False
# 2022-12-31  27221.552795  158.084211  15.974262          NaN            False
#
# [9859 rows x 5 columns]

# %%
# Count the number of True and False values in the 'is_valid' column
value_counts = df['eoliene_can_run'].value_counts()

# Plot a pie chart of the value counts
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.title('% of days eoliene can run')
plt.show()
